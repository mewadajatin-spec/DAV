# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/codebasics/py/refs/heads/master/pandas/14_ts_datetimeindex/aapl.csv', parse_dates = ['Date'], index_col='Date')
df.head()
# Out:
# /tmp/ipykernel_5454/3113247348.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('https://raw.githubusercontent.com/codebasics/py/refs/heads/master/pandas/14_ts_datetimeindex/aapl.csv', parse_dates = ['Date'], index_col='Date')
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# # Retrive 2017 Stock Prices

# %% [markdown]
# # Find Average price of Apple's stock in Jan 2017

# %%
df.loc['2017-01'].Close.mean()
# Out:
# np.float64(119.57000000000001)

# %%
df.loc["2017-01-03", 'Close']
# Out:
# np.float64(116.15)

# %%
df.loc["2017-01-03"].Close
# Out:
# np.float64(116.15)

# %%
df = df.sort_index()
df.loc['2017-01-01': '2017-01-07']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-03  115.80  116.33  114.76  116.15  28781865
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-06  116.78  118.16  116.47  117.91  31751900

# %%
df.Close.resample('M').mean()
# Out:
# /tmp/ipykernel_5454/3510564528.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean()
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: ME, Name: Close, dtype: float64

# %%
df.Close.resample('M').mean().plot()
# Out:
# /tmp/ipykernel_5454/4123725665.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('W').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Q').mean().plot()
# Out:
# /tmp/ipykernel_5454/3189526837.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Q').mean().plot(kind='bar')
# Out:
# /tmp/ipykernel_5454/2118656906.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot(kind='bar')
# <Axes: xlabel='Date'>
